# %% [markdown]
# <a href="https://colab.research.google.com/github/JacobeCode/Neural_Network_For_Speech_Recognition/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install theano
# !pip install speechpy

# Main modules import
import keras
import librosa
import tensorflow
import os
import datetime
import speechpy

# Side modules import
import numpy as np
import theano as te
import matplotlib as plt
import pandas as pd

# Needed parts - import
from pathlib import Path
from google.colab import drive
from datetime import datetime
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Activation, Reshape, Flatten, LSTM, Conv2D, MaxPooling2D
from keras.optimizers import Adam, SGD
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.losses import categorical_crossentropy, binary_crossentropy, sparse_categorical_crossentropy
from keras.utils.np_utils import to_categorical
from IPython.display import Audio, display
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split, KFold, LeaveOneOut, StratifiedKFold

# Root directory for files - for different directory - change here

# Python local version

# root_dir = Path.cwd()
# train_set_dir = os.path.join(Path.cwd(), "Recordings")
# train_set_list = os.listdir(train_set_dir)
# eval_set_dir = os.path.join(Path.cwd(), "Eval_Recordings")
# eval_set_list = os.listdir(eval_set_dir)

# Colab with Drive version
drive.mount('/content/gdrive/')

root_dir = '/content/gdrive/MyDrive/Speech_Recognition'
model_dir = '/content/gdrive/MyDrive/Speech_Recognition/Model'
CSV_dir = '/content/gdrive/MyDrive/Speech_Recognition/CSV'
train_set_dir = '/content/gdrive/MyDrive/Speech_Recognition/Recordings'
train_set_list = os.listdir(train_set_dir)
eval_set_dir = '/content/gdrive/MyDrive/Speech_Recognition/Eval_Recordings'
eval_set_list = os.listdir(eval_set_dir)
os.chdir(root_dir)
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: theano in /usr/local/lib/python3.8/dist-packages (1.0.5)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.8/dist-packages (from theano) (1.15.0)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.8/dist-packages (from theano) (1.7.3)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.8/dist-packages (from theano) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: speechpy in /usr/local/lib/python3.8/dist-packages (2.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.8/dist-packages (from speechpy) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from speechpy) (1.7.3)
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %%
# Parameters for comfortable changes later
n_mfcc = 13                                     # Number of MFCC coefficients
win_length = 512                                # Length of MFCC window
n_batch_size = 128                              # Batch Size
n_epoch = 10                                    # Number of Epoch's to perform

add_display = 1
loss_function = 'categorical_crossentropy'      # Type of loss function
optimizer = 'SGD'                              # Type of optimizer
metric_type = 'accuracy'                        # Type of testing metric
test_percentage = 0.1                           # How much of data will be selected to test the training

# %%
# Data pre-processing - building database
eval_set_base = pd.DataFrame()

os.chdir(eval_set_dir)
MFCC_list = []
delta_list = []
records = []
for count, audio in enumerate(eval_set_list):
    data, fs = librosa.load(audio, sr=None)
    data = data/max(np.abs(data))
    for iteration, item in enumerate(data):
        if np.abs(item) < 0.01:
            np.delete(data, iteration)
    MFCC = librosa.feature.mfcc(y=data, sr=fs, n_mfcc=n_mfcc, hop_length=int(win_length/2), win_length=win_length, n_fft=win_length)
    MFCC_list.append(MFCC)
    records.append(audio)
MFCC_temp = []
max_len = max(np.shape(x)[1] for x in MFCC_list)
for item in MFCC_list:
    temp = []
    n_add = max_len - np.shape(item)[1]
    for coeff in item:
      temp.append(np.append(coeff, np.zeros(n_add)))
    MFCC_temp.append(temp)
    del temp
MFCC_list = MFCC_temp
del MFCC_temp

for item in MFCC_list:
    np.reshape(item, (n_mfcc, max_len, 1))

eval_set_base["Record"] = records
eval_set_base["MFCC"] = MFCC_list
os.chdir(root_dir)

del MFCC_list
del records

# %%
# Data pre-processing - building database
train_set_base = pd.DataFrame()

os.chdir(train_set_dir)
MFCC_list = []
labels = []
records = []
for count, audio in enumerate(train_set_list):
    data, fs = librosa.load(audio, sr=None)
    data = data/max(np.abs(data))
    for iteration, item in enumerate(data):
        if np.abs(item) < 0.01:
            np.delete(data, iteration)
    MFCC = librosa.feature.mfcc(y=data, sr=fs, n_mfcc=n_mfcc, hop_length=int(win_length/2), win_length=win_length, n_fft=win_length)
    labels.append(audio[6])
    records.append(audio)
    MFCC_list.append(MFCC)
MFCC_temp = []
for item in MFCC_list:
    temp = []
    n_add = max_len - np.shape(item)[1]
    for coeff in item:
      temp.append(np.append(coeff, np.zeros(n_add)))
    MFCC_temp.append(temp)
    del temp
MFCC_list = MFCC_temp
del MFCC_temp

for item in MFCC_list:
    np.reshape(item, (n_mfcc, max_len, 1))

train_set_base["Record"] = records
train_set_base["MFCC"] = MFCC_list
train_set_base["Labels"] = labels
os.chdir(root_dir)

del MFCC_list
del labels
del records

# %%
# CMVN Normalization

for count, item in enumerate(train_set_base["MFCC"]):
    train_set_base["MFCC"].replace(speechpy.processing.cmvn(np.asarray(item)))

# %%
for count, item in enumerate(eval_set_base["MFCC"]):
    eval_set_base["MFCC"].replace(speechpy.processing.cmvn(np.asarray(item)))

# %%
print("Training Recordings database : ")
display(train_set_base)

print("Eval Recordings database : ")
display(eval_set_base)
# Out:
# Training Recordings database :
#            Record                                               MFCC Labels
# 0    AO1M1_2_.wav  [[-662.9744262695312, -631.0436401367188, -568...      2
# 1    AO1M1_0_.wav  [[-612.0942993164062, -573.1663818359375, -417...      0
# 2    AO1M1_1_.wav  [[-571.8582763671875, -549.147216796875, -550....      1
# 3    AO1M1_3_.wav  [[-595.4745483398438, -432.62554931640625, -26...      3
# 4    AO1M1_9_.wav  [[-618.9461669921875, -591.8220825195312, -412...      9
# ..            ...                                                ...    ...
# 215  SW1M1_8_.wav  [[-590.7490234375, -406.0035705566406, -288.78...      8
# 216  SW1M1_3_.wav  [[-614.0647583007812, -439.59356689453125, -23...      3
# 217  SW1M1_5_.wav  [[-672.4749145507812, -453.1002502441406, -306...      5
# 218  SW1M1_7_.wav  [[-596.5587768554688, -483.9967041015625, -410...      7
# 219  SW1M1_4_.wav  [[-570.9442749023438, -456.9549865722656, -289...      4
#
# [220 rows x 3 columns]
# Eval Recordings database :
#       Record                                               MFCC
# 0    040.wav  [[-638.1614990234375, -542.1619262695312, -438...
# 1    058.wav  [[-344.8790588378906, -298.9581298828125, -290...
# 2    004.wav  [[-618.7013549804688, -599.5948486328125, -599...
# 3    029.wav  [[-402.5004577636719, -392.03924560546875, -39...
# 4    064.wav  [[-449.2403259277344, -417.07275390625, -429.5...
# ..       ...                                                ...
# 655  650.wav  [[-487.6944274902344, -455.0632629394531, -414...
# 656  647.wav  [[-548.4116821289062, -543.112060546875, -549....
# 657  643.wav  [[-615.047607421875, -604.5725708007812, -602....
# 658  639.wav  [[-609.5606689453125, -601.455322265625, -310....
# 659  660.wav  [[-490.537109375, -483.3124084472656, -411.366...
#
# [660 rows x 2 columns]

# %%
model = Sequential()
model.add(Conv2D(32, (6,6), padding="valid", activation="relu", input_shape=(n_mfcc, max_len, 1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(16, (3,3), padding="valid", activation="relu", input_shape=(n_mfcc/2, max_len/2, 1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Flatten(input_shape=(n_mfcc/4, max_len/4, 1)))
model.add(Activation('relu'))
model.add(Dense(128))
model.add(Dropout(0.5))
model.add(Activation('relu'))
model.add(Dense(10))
model.add(Activation('softmax'))

if optimizer == 'Adam':
    adam = Adam(learning_rate=0.001)
    model.compile(loss=loss_function, metrics=[metric_type, loss_function], optimizer=adam)
elif optimizer == 'SGD':
    sgd = SGD(learning_rate=0.001)
    model.compile(loss=loss_function, metrics=[metric_type, loss_function], optimizer=sgd)

model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 8, 121, 32)        1184
#
#  max_pooling2d_8 (MaxPooling  (None, 4, 60, 32)        0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 2, 58, 16)         4624
#
#  max_pooling2d_9 (MaxPooling  (None, 1, 29, 16)        0
#  2D)
#
#  flatten_4 (Flatten)         (None, 464)               0
#
#  activation_13 (Activation)  (None, 464)               0
#
#  dense_9 (Dense)             (None, 128)               59520
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  activation_14 (Activation)  (None, 128)               0
#
#  dense_10 (Dense)            (None, 10)                1290
#
#  activation_15 (Activation)  (None, 10)                0
#
# =================================================================
# Total params: 66,618
# Trainable params: 66,618
# Non-trainable params: 0
# _________________________________________________________________

# %%
X = np.array(train_set_base['MFCC'].tolist())
y_true = train_set_base['Labels'].tolist()

label_encoder = LabelEncoder()
y_true = to_categorical(label_encoder.fit_transform(y_true))

acc_per_fold = []
loss_per_fold = []
i = 0
kf = KFold(n_splits = 11)

# X_train, X_test, y_train, y_test = train_test_split(X, y_true, test_size=test_percentage, random_state=42)

for train_index, test_index in kf.split(X,  y_true):
    # print("TRAIN:", train_index, "TEST:", test_index)
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = y_true[train_index], y_true[test_index]
    start = datetime.now()
    history = model.fit(X_train, y_train, batch_size=n_batch_size, epochs=n_epoch, validation_data=(X_test, y_test), verbose=add_display)
    duration = datetime.now() - start

    results = model.evaluate(X_test, y_test, verbose=add_display)
    
    print(f'Score for fold {i}: {model.metrics_names[0]} of {results[0]}; {model.metrics_names[1]} of {results[1]*100}%')
    acc_per_fold.append(results[1] * 100)
    loss_per_fold.append(results[0])
    i += 1

print('Accuracy: ')
print(np.mean(acc_per_fold))
print('Loss: ')
print(np.mean(loss_per_fold))
del start
# Out:
# Epoch 1/10
# 2/2 [==============================] - 1s 208ms/step - loss: 21.3438 - accuracy: 0.1050 - categorical_crossentropy: 21.3438 - val_loss: 4.0292 - val_accuracy: 0.0500 - val_categorical_crossentropy: 4.0292
# Epoch 2/10
# 2/2 [==============================] - 0s 28ms/step - loss: 5.8485 - accuracy: 0.1200 - categorical_crossentropy: 5.8485 - val_loss: 3.0594 - val_accuracy: 0.2000 - val_categorical_crossentropy: 3.0594
# Epoch 3/10
# 2/2 [==============================] - 0s 32ms/step - loss: 4.7714 - accuracy: 0.1300 - categorical_crossentropy: 4.7714 - val_loss: 2.5122 - val_accuracy: 0.2000 - val_categorical_crossentropy: 2.5122
# Epoch 4/10
# 2/2 [==============================] - 0s 27ms/step - loss: 3.5353 - accuracy: 0.1550 - categorical_crossentropy: 3.5353 - val_loss: 2.3210 - val_accuracy: 0.2000 - val_categorical_crossentropy: 2.3210
# Epoch 5/10
# 2/2 [==============================] - 0s 33ms/step - loss: 3.0848 - accuracy: 0.1650 - categorical_crossentropy: 3.0848 - val_loss: 2.2368 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.2368
# Epoch 6/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.9759 - accuracy: 0.1050 - categorical_crossentropy: 2.9759 - val_loss: 2.2600 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.2600
# Epoch 7/10
# 2/2 [==============================] - 0s 26ms/step - loss: 2.6960 - accuracy: 0.1350 - categorical_crossentropy: 2.6960 - val_loss: 2.2856 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.2856
# Epoch 8/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.6836 - accuracy: 0.1250 - categorical_crossentropy: 2.6836 - val_loss: 2.2648 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.2648
# Epoch 9/10
# 2/2 [==============================] - 0s 30ms/step - loss: 2.5027 - accuracy: 0.1650 - categorical_crossentropy: 2.5027 - val_loss: 2.2700 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.2700
# Epoch 10/10
# 2/2 [==============================] - 0s 28ms/step - loss: 2.3609 - accuracy: 0.2050 - categorical_crossentropy: 2.3609 - val_loss: 2.2536 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.2536
# 1/1 [==============================] - 0s 22ms/step - loss: 2.2536 - accuracy: 0.2500 - categorical_crossentropy: 2.2536
# Score for fold 0: loss of 2.253592014312744; accuracy of 25.0%
# Epoch 1/10
# 2/2 [==============================] - 0s 52ms/step - loss: 2.4617 - accuracy: 0.1100 - categorical_crossentropy: 2.4617 - val_loss: 2.2428 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.2428
# Epoch 2/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.4359 - accuracy: 0.1800 - categorical_crossentropy: 2.4359 - val_loss: 2.2146 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.2146
# Epoch 3/10
# 2/2 [==============================] - 0s 26ms/step - loss: 2.3652 - accuracy: 0.1450 - categorical_crossentropy: 2.3652 - val_loss: 2.2225 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.2225
# Epoch 4/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.3154 - accuracy: 0.1950 - categorical_crossentropy: 2.3154 - val_loss: 2.1863 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.1863
# Epoch 5/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.3233 - accuracy: 0.1750 - categorical_crossentropy: 2.3233 - val_loss: 2.1764 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.1764
# Epoch 6/10
# 2/2 [==============================] - 0s 26ms/step - loss: 2.3079 - accuracy: 0.1700 - categorical_crossentropy: 2.3079 - val_loss: 2.1863 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.1863
# Epoch 7/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.2624 - accuracy: 0.1750 - categorical_crossentropy: 2.2624 - val_loss: 2.1787 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.1787
# Epoch 8/10
# 2/2 [==============================] - 0s 26ms/step - loss: 2.2225 - accuracy: 0.1800 - categorical_crossentropy: 2.2225 - val_loss: 2.1861 - val_accuracy: 0.2000 - val_categorical_crossentropy: 2.1861
# Epoch 9/10
# 2/2 [==============================] - 0s 30ms/step - loss: 2.2987 - accuracy: 0.1800 - categorical_crossentropy: 2.2987 - val_loss: 2.1749 - val_accuracy: 0.1000 - val_categorical_crossentropy: 2.1749
# Epoch 10/10
# 2/2 [==============================] - 0s 26ms/step - loss: 2.2284 - accuracy: 0.2000 - categorical_crossentropy: 2.2284 - val_loss: 2.2043 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.2043
# 1/1 [==============================] - 0s 21ms/step - loss: 2.2043 - accuracy: 0.1500 - categorical_crossentropy: 2.2043
# Score for fold 1: loss of 2.20428729057312; accuracy of 15.000000596046448%
# Epoch 1/10
# 2/2 [==============================] - 0s 404ms/step - loss: 2.2676 - accuracy: 0.1450 - categorical_crossentropy: 2.2676 - val_loss: 2.0226 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.0226
# Epoch 2/10
# 2/2 [==============================] - 0s 28ms/step - loss: 2.1613 - accuracy: 0.2200 - categorical_crossentropy: 2.1613 - val_loss: 2.0189 - val_accuracy: 0.2500 - val_categorical_crossentropy: 2.0189
# Epoch 3/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.2416 - accuracy: 0.1550 - categorical_crossentropy: 2.2416 - val_loss: 2.0068 - val_accuracy: 0.2000 - val_categorical_crossentropy: 2.0068
# Epoch 4/10
# 2/2 [==============================] - 0s 32ms/step - loss: 2.1389 - accuracy: 0.1650 - categorical_crossentropy: 2.1389 - val_loss: 2.0339 - val_accuracy: 0.1500 - val_categorical_crossentropy: 2.0339
# Epoch 5/10
# 2/2 [==============================] - 0s 30ms/step - loss: 2.1404 - accuracy: 0.2050 - categorical_crossentropy: 2.1404 - val_loss: 1.9929 - val_accuracy: 0.2500 - val_categorical_crossentropy: 1.9929
# Epoch 6/10
# 2/2 [==============================] - 0s 29ms/step - loss: 2.1708 - accuracy: 0.2350 - categorical_crossentropy: 2.1708 - val_loss: 1.9976 - val_accuracy: 0.2500 - val_categorical_crossentropy: 1.9976
# Epoch 7/10
# 2/2 [==============================] - 0s 35ms/step - loss: 2.0322 - accuracy: 0.2700 - categorical_crossentropy: 2.0322 - val_loss: 1.9862 - val_accuracy: 0.2500 - val_categorical_crossentropy: 1.9862
# Epoch 8/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0728 - accuracy: 0.2150 - categorical_crossentropy: 2.0728 - val_loss: 1.9645 - val_accuracy: 0.2500 - val_categorical_crossentropy: 1.9645
# Epoch 9/10
# 2/2 [==============================] - 0s 29ms/step - loss: 2.0408 - accuracy: 0.2150 - categorical_crossentropy: 2.0408 - val_loss: 2.0078 - val_accuracy: 0.3000 - val_categorical_crossentropy: 2.0078
# Epoch 10/10
# 2/2 [==============================] - 0s 33ms/step - loss: 2.0016 - accuracy: 0.2650 - categorical_crossentropy: 2.0016 - val_loss: 2.0050 - val_accuracy: 0.3000 - val_categorical_crossentropy: 2.0050
# 1/1 [==============================] - 0s 21ms/step - loss: 2.0050 - accuracy: 0.3000 - categorical_crossentropy: 2.0050
# Score for fold 2: loss of 2.005000114440918; accuracy of 30.000001192092896%
# Epoch 1/10
# 2/2 [==============================] - 0s 61ms/step - loss: 2.0297 - accuracy: 0.2350 - categorical_crossentropy: 2.0297 - val_loss: 1.8087 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.8087
# Epoch 2/10
# 2/2 [==============================] - 0s 28ms/step - loss: 2.0541 - accuracy: 0.2400 - categorical_crossentropy: 2.0541 - val_loss: 1.8350 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.8350
# Epoch 3/10
# 2/2 [==============================] - 0s 35ms/step - loss: 2.0517 - accuracy: 0.2650 - categorical_crossentropy: 2.0517 - val_loss: 1.8757 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.8757
# Epoch 4/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0173 - accuracy: 0.2900 - categorical_crossentropy: 2.0173 - val_loss: 1.8266 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.8266
# Epoch 5/10
# 2/2 [==============================] - 0s 42ms/step - loss: 2.1347 - accuracy: 0.2050 - categorical_crossentropy: 2.1347 - val_loss: 1.8521 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.8521
# Epoch 6/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0090 - accuracy: 0.2550 - categorical_crossentropy: 2.0090 - val_loss: 1.8023 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.8023
# Epoch 7/10
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0607 - accuracy: 0.2050 - categorical_crossentropy: 2.0607 - val_loss: 1.8157 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.8157
# Epoch 8/10
# 2/2 [==============================] - 0s 30ms/step - loss: 2.0259 - accuracy: 0.2500 - categorical_crossentropy: 2.0259 - val_loss: 1.8222 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.8222
# Epoch 9/10
# 2/2 [==============================] - 0s 26ms/step - loss: 2.0402 - accuracy: 0.2550 - categorical_crossentropy: 2.0402 - val_loss: 1.7913 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.7913
# Epoch 10/10
# 2/2 [==============================] - 0s 25ms/step - loss: 2.0675 - accuracy: 0.2300 - categorical_crossentropy: 2.0675 - val_loss: 1.7764 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.7764
# 1/1 [==============================] - 0s 19ms/step - loss: 1.7764 - accuracy: 0.4500 - categorical_crossentropy: 1.7764
# Score for fold 3: loss of 1.7763532400131226; accuracy of 44.999998807907104%
# Epoch 1/10
# 2/2 [==============================] - 0s 56ms/step - loss: 1.9908 - accuracy: 0.2800 - categorical_crossentropy: 1.9908 - val_loss: 1.8820 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.8820
# Epoch 2/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.9360 - accuracy: 0.3000 - categorical_crossentropy: 1.9360 - val_loss: 1.9212 - val_accuracy: 0.2500 - val_categorical_crossentropy: 1.9212
# Epoch 3/10
# 2/2 [==============================] - 0s 27ms/step - loss: 2.0017 - accuracy: 0.3050 - categorical_crossentropy: 2.0017 - val_loss: 1.9007 - val_accuracy: 0.3500 - val_categorical_crossentropy: 1.9007
# Epoch 4/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9355 - accuracy: 0.2850 - categorical_crossentropy: 1.9355 - val_loss: 1.8743 - val_accuracy: 0.3000 - val_categorical_crossentropy: 1.8743
# Epoch 5/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.9722 - accuracy: 0.3100 - categorical_crossentropy: 1.9722 - val_loss: 1.9206 - val_accuracy: 0.2500 - val_categorical_crossentropy: 1.9206
# Epoch 6/10
# 2/2 [==============================] - 0s 29ms/step - loss: 1.9434 - accuracy: 0.2700 - categorical_crossentropy: 1.9434 - val_loss: 1.8722 - val_accuracy: 0.3500 - val_categorical_crossentropy: 1.8722
# Epoch 7/10
# 2/2 [==============================] - 0s 29ms/step - loss: 1.9203 - accuracy: 0.2850 - categorical_crossentropy: 1.9203 - val_loss: 1.8687 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.8687
# Epoch 8/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.8730 - accuracy: 0.3100 - categorical_crossentropy: 1.8730 - val_loss: 1.8761 - val_accuracy: 0.3500 - val_categorical_crossentropy: 1.8761
# Epoch 9/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.8926 - accuracy: 0.3150 - categorical_crossentropy: 1.8926 - val_loss: 1.8653 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.8653
# Epoch 10/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.9061 - accuracy: 0.3000 - categorical_crossentropy: 1.9061 - val_loss: 1.8677 - val_accuracy: 0.4000 - val_categorical_crossentropy: 1.8677
# 1/1 [==============================] - 0s 19ms/step - loss: 1.8677 - accuracy: 0.4000 - categorical_crossentropy: 1.8677
# Score for fold 4: loss of 1.8676681518554688; accuracy of 40.00000059604645%
# Epoch 1/10
# 2/2 [==============================] - 0s 59ms/step - loss: 1.9226 - accuracy: 0.3050 - categorical_crossentropy: 1.9226 - val_loss: 1.6609 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.6609
# Epoch 2/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.9182 - accuracy: 0.2900 - categorical_crossentropy: 1.9182 - val_loss: 1.6704 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.6704
# Epoch 3/10
# 2/2 [==============================] - 0s 34ms/step - loss: 1.9119 - accuracy: 0.3150 - categorical_crossentropy: 1.9119 - val_loss: 1.6880 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.6880
# Epoch 4/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.8575 - accuracy: 0.3100 - categorical_crossentropy: 1.8575 - val_loss: 1.6686 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.6686
# Epoch 5/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.9279 - accuracy: 0.3300 - categorical_crossentropy: 1.9279 - val_loss: 1.6395 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.6395
# Epoch 6/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.8305 - accuracy: 0.3200 - categorical_crossentropy: 1.8305 - val_loss: 1.6279 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.6279
# Epoch 7/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.7414 - accuracy: 0.3550 - categorical_crossentropy: 1.7414 - val_loss: 1.6401 - val_accuracy: 0.4500 - val_categorical_crossentropy: 1.6401
# Epoch 8/10
# 2/2 [==============================] - 0s 29ms/step - loss: 1.8402 - accuracy: 0.3200 - categorical_crossentropy: 1.8402 - val_loss: 1.6422 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.6422
# Epoch 9/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.8500 - accuracy: 0.2900 - categorical_crossentropy: 1.8500 - val_loss: 1.6282 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.6282
# Epoch 10/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.8795 - accuracy: 0.3400 - categorical_crossentropy: 1.8795 - val_loss: 1.6241 - val_accuracy: 0.5000 - val_categorical_crossentropy: 1.6241
# 1/1 [==============================] - 0s 22ms/step - loss: 1.6241 - accuracy: 0.5000 - categorical_crossentropy: 1.6241
# Score for fold 5: loss of 1.6240657567977905; accuracy of 50.0%
# Epoch 1/10
# 2/2 [==============================] - 0s 53ms/step - loss: 1.8689 - accuracy: 0.3300 - categorical_crossentropy: 1.8689 - val_loss: 1.5571 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.5571
# Epoch 2/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.8333 - accuracy: 0.3400 - categorical_crossentropy: 1.8333 - val_loss: 1.5836 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.5836
# Epoch 3/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.8845 - accuracy: 0.3750 - categorical_crossentropy: 1.8845 - val_loss: 1.5298 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.5298
# Epoch 4/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.7497 - accuracy: 0.3850 - categorical_crossentropy: 1.7497 - val_loss: 1.5143 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.5143
# Epoch 5/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.6727 - accuracy: 0.4050 - categorical_crossentropy: 1.6727 - val_loss: 1.5123 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.5123
# Epoch 6/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.7585 - accuracy: 0.3500 - categorical_crossentropy: 1.7585 - val_loss: 1.5855 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.5855
# Epoch 7/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.7640 - accuracy: 0.3500 - categorical_crossentropy: 1.7640 - val_loss: 1.4657 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.4657
# Epoch 8/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.7194 - accuracy: 0.4100 - categorical_crossentropy: 1.7194 - val_loss: 1.4972 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.4972
# Epoch 9/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.7459 - accuracy: 0.4000 - categorical_crossentropy: 1.7459 - val_loss: 1.4737 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.4737
# Epoch 10/10
# 2/2 [==============================] - 0s 29ms/step - loss: 1.6920 - accuracy: 0.4050 - categorical_crossentropy: 1.6920 - val_loss: 1.4294 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.4294
# 1/1 [==============================] - 0s 19ms/step - loss: 1.4294 - accuracy: 0.6500 - categorical_crossentropy: 1.4294
# Score for fold 6: loss of 1.4293724298477173; accuracy of 64.99999761581421%
# Epoch 1/10
# 2/2 [==============================] - 0s 62ms/step - loss: 1.6969 - accuracy: 0.3750 - categorical_crossentropy: 1.6969 - val_loss: 1.4549 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.4549
# Epoch 2/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.7244 - accuracy: 0.3500 - categorical_crossentropy: 1.7244 - val_loss: 1.5052 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.5052
# Epoch 3/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.6877 - accuracy: 0.3800 - categorical_crossentropy: 1.6877 - val_loss: 1.5382 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.5382
# Epoch 4/10
# 2/2 [==============================] - 0s 34ms/step - loss: 1.7314 - accuracy: 0.3750 - categorical_crossentropy: 1.7314 - val_loss: 1.5223 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.5223
# Epoch 5/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.7074 - accuracy: 0.3700 - categorical_crossentropy: 1.7074 - val_loss: 1.5247 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.5247
# Epoch 6/10
# 2/2 [==============================] - 0s 28ms/step - loss: 1.6389 - accuracy: 0.4400 - categorical_crossentropy: 1.6389 - val_loss: 1.4288 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.4288
# Epoch 7/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.6949 - accuracy: 0.4100 - categorical_crossentropy: 1.6949 - val_loss: 1.5290 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.5290
# Epoch 8/10
# 2/2 [==============================] - 0s 30ms/step - loss: 1.5951 - accuracy: 0.4600 - categorical_crossentropy: 1.5951 - val_loss: 1.3952 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.3952
# Epoch 9/10
# 2/2 [==============================] - 0s 27ms/step - loss: 1.6076 - accuracy: 0.4250 - categorical_crossentropy: 1.6076 - val_loss: 1.4820 - val_accuracy: 0.5500 - val_categorical_crossentropy: 1.4820
# Epoch 10/10
# 2/2 [==============================] - 0s 26ms/step - loss: 1.6118 - accuracy: 0.4700 - categorical_crossentropy: 1.6118 - val_loss: 1.4337 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.4337
# 1/1 [==============================] - 0s 27ms/step - loss: 1.4337 - accuracy: 0.6000 - categorical_crossentropy: 1.4337
# Score for fold 7: loss of 1.433711051940918; accuracy of 60.00000238418579%
# Epoch 1/10
# 2/2 [==============================] - 0s 90ms/step - loss: 1.5686 - accuracy: 0.4800 - categorical_crossentropy: 1.5686 - val_loss: 1.3753 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.3753
# Epoch 2/10
# 2/2 [==============================] - 0s 37ms/step - loss: 1.6221 - accuracy: 0.4250 - categorical_crossentropy: 1.6221 - val_loss: 1.4042 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.4042
# Epoch 3/10
# 2/2 [==============================] - 0s 36ms/step - loss: 1.6627 - accuracy: 0.4100 - categorical_crossentropy: 1.6627 - val_loss: 1.3623 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.3623
# Epoch 4/10
# 2/2 [==============================] - 0s 38ms/step - loss: 1.6147 - accuracy: 0.4150 - categorical_crossentropy: 1.6147 - val_loss: 1.3779 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.3779
# Epoch 5/10
# 2/2 [==============================] - 0s 36ms/step - loss: 1.4855 - accuracy: 0.4850 - categorical_crossentropy: 1.4855 - val_loss: 1.3553 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.3553
# Epoch 6/10
# 2/2 [==============================] - 0s 42ms/step - loss: 1.6333 - accuracy: 0.4200 - categorical_crossentropy: 1.6333 - val_loss: 1.3801 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.3801
# Epoch 7/10
# 2/2 [==============================] - 0s 40ms/step - loss: 1.5336 - accuracy: 0.5300 - categorical_crossentropy: 1.5336 - val_loss: 1.3737 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.3737
# Epoch 8/10
# 2/2 [==============================] - 0s 44ms/step - loss: 1.5228 - accuracy: 0.4600 - categorical_crossentropy: 1.5228 - val_loss: 1.3396 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.3396
# Epoch 9/10
# 2/2 [==============================] - 0s 44ms/step - loss: 1.4579 - accuracy: 0.4850 - categorical_crossentropy: 1.4579 - val_loss: 1.3198 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.3198
# Epoch 10/10
# 2/2 [==============================] - 0s 37ms/step - loss: 1.5067 - accuracy: 0.4950 - categorical_crossentropy: 1.5067 - val_loss: 1.3526 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.3526
# 1/1 [==============================] - 0s 29ms/step - loss: 1.3526 - accuracy: 0.6500 - categorical_crossentropy: 1.3526
# Score for fold 8: loss of 1.3525731563568115; accuracy of 64.99999761581421%
# Epoch 1/10
# 2/2 [==============================] - 0s 76ms/step - loss: 1.5537 - accuracy: 0.4350 - categorical_crossentropy: 1.5537 - val_loss: 1.2249 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.2249
# Epoch 2/10
# 2/2 [==============================] - 0s 33ms/step - loss: 1.4770 - accuracy: 0.4800 - categorical_crossentropy: 1.4770 - val_loss: 1.2149 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.2149
# Epoch 3/10
# 2/2 [==============================] - 0s 33ms/step - loss: 1.4137 - accuracy: 0.5000 - categorical_crossentropy: 1.4137 - val_loss: 1.1977 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.1977
# Epoch 4/10
# 2/2 [==============================] - 0s 33ms/step - loss: 1.5410 - accuracy: 0.4450 - categorical_crossentropy: 1.5410 - val_loss: 1.2063 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.2063
# Epoch 5/10
# 2/2 [==============================] - 0s 33ms/step - loss: 1.5298 - accuracy: 0.4750 - categorical_crossentropy: 1.5298 - val_loss: 1.2130 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.2130
# Epoch 6/10
# 2/2 [==============================] - 0s 33ms/step - loss: 1.3735 - accuracy: 0.5400 - categorical_crossentropy: 1.3735 - val_loss: 1.2134 - val_accuracy: 0.6000 - val_categorical_crossentropy: 1.2134
# Epoch 7/10
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4537 - accuracy: 0.5000 - categorical_crossentropy: 1.4537 - val_loss: 1.2631 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.2631
# Epoch 8/10
# 2/2 [==============================] - 0s 43ms/step - loss: 1.4648 - accuracy: 0.5150 - categorical_crossentropy: 1.4648 - val_loss: 1.2164 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.2164
# Epoch 9/10
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4424 - accuracy: 0.5200 - categorical_crossentropy: 1.4424 - val_loss: 1.2209 - val_accuracy: 0.7500 - val_categorical_crossentropy: 1.2209
# Epoch 10/10
# 2/2 [==============================] - 0s 39ms/step - loss: 1.3879 - accuracy: 0.5250 - categorical_crossentropy: 1.3879 - val_loss: 1.2375 - val_accuracy: 0.6500 - val_categorical_crossentropy: 1.2375
# 1/1 [==============================] - 0s 30ms/step - loss: 1.2375 - accuracy: 0.6500 - categorical_crossentropy: 1.2375
# Score for fold 9: loss of 1.2374598979949951; accuracy of 64.99999761581421%
# Epoch 1/10
# 2/2 [==============================] - 0s 91ms/step - loss: 1.4945 - accuracy: 0.4850 - categorical_crossentropy: 1.4945 - val_loss: 1.1627 - val_accuracy: 0.8500 - val_categorical_crossentropy: 1.1627
# Epoch 2/10
# 2/2 [==============================] - 0s 41ms/step - loss: 1.4049 - accuracy: 0.5100 - categorical_crossentropy: 1.4049 - val_loss: 1.1285 - val_accuracy: 0.8000 - val_categorical_crossentropy: 1.1285
# Epoch 3/10
# 2/2 [==============================] - 0s 46ms/step - loss: 1.3965 - accuracy: 0.4800 - categorical_crossentropy: 1.3965 - val_loss: 1.1368 - val_accuracy: 1.0000 - val_categorical_crossentropy: 1.1368
# Epoch 4/10
# 2/2 [==============================] - 0s 38ms/step - loss: 1.3557 - accuracy: 0.5850 - categorical_crossentropy: 1.3557 - val_loss: 1.1505 - val_accuracy: 0.7500 - val_categorical_crossentropy: 1.1505
# Epoch 5/10
# 2/2 [==============================] - 0s 37ms/step - loss: 1.3184 - accuracy: 0.5650 - categorical_crossentropy: 1.3184 - val_loss: 1.1056 - val_accuracy: 0.9000 - val_categorical_crossentropy: 1.1056
# Epoch 6/10
# 2/2 [==============================] - 0s 36ms/step - loss: 1.3142 - accuracy: 0.5300 - categorical_crossentropy: 1.3142 - val_loss: 1.1012 - val_accuracy: 0.8500 - val_categorical_crossentropy: 1.1012
# Epoch 7/10
# 2/2 [==============================] - 0s 34ms/step - loss: 1.4672 - accuracy: 0.4750 - categorical_crossentropy: 1.4672 - val_loss: 1.1120 - val_accuracy: 0.7500 - val_categorical_crossentropy: 1.1120
# Epoch 8/10
# 2/2 [==============================] - 0s 37ms/step - loss: 1.3024 - accuracy: 0.5250 - categorical_crossentropy: 1.3024 - val_loss: 1.1372 - val_accuracy: 0.7500 - val_categorical_crossentropy: 1.1372
# Epoch 9/10
# 2/2 [==============================] - 0s 37ms/step - loss: 1.3750 - accuracy: 0.4850 - categorical_crossentropy: 1.3750 - val_loss: 1.1380 - val_accuracy: 0.7000 - val_categorical_crossentropy: 1.1380
# Epoch 10/10
# 2/2 [==============================] - 0s 32ms/step - loss: 1.3310 - accuracy: 0.5200 - categorical_crossentropy: 1.3310 - val_loss: 1.1110 - val_accuracy: 0.9500 - val_categorical_crossentropy: 1.1110
# 1/1 [==============================] - 0s 29ms/step - loss: 1.1110 - accuracy: 0.9500 - categorical_crossentropy: 1.1110
# Score for fold 10: loss of 1.1110321283340454; accuracy of 94.9999988079071%
# Accuracy:
# 50.45454502105713
# Loss:
# 1.6631922938606956

# %%
model.save(model_dir)
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 2 of 2). These functions will not be directly callable after loading.

# %%
model = load_model(model_dir)
X = np.array(eval_set_base['MFCC'].tolist())
predict = model.predict(X)

values_from_prediction = []
for item in predict:
    values_from_prediction.append(np.max(item))
class_predictions = np.argmax(predict, axis=-1)
print(class_predictions)

rd={"file": eval_set_base['Record'],
        "prediction":class_predictions,
      "values":values_from_prediction}
results_to_csv=pd.DataFrame(data=rd)
print(results_to_csv)
os.chdir(CSV_dir)
results_to_csv.to_csv('results_ia.csv', index=False, header = False, sep = ',')
os.chdir(root_dir)
# Out:
# 21/21 [==============================] - 0s 2ms/step
# [6 8 6 2 7 4 2 2 6 0 8 1 6 6 5 6 4 8 8 9 5 5 6 7 0 5 0 3 9 6 9 7 9 7 6 3 2
#  9 5 9 4 9 7 3 6 9 7 9 9 0 6 6 6 9 8 6 7 9 9 4 9 1 2 6 9 6 7 8 9 8 5 9 9 4
#  0 1 8 1 1 9 1 2 9 4 7 4 5 9 0 3 4 7 9 2 2 3 8 1 7 4 2 9 0 3 7 9 5 2 2 0 1
#  6 3 1 3 5 9 4 7 5 4 8 8 6 7 6 7 5 2 2 1 6 9 7 3 1 3 0 7 2 1 8 0 9 2 5 3 9
#  7 5 2 9 5 5 7 6 8 2 3 5 5 1 3 6 5 9 1 0 0 7 3 1 9 8 5 5 6 2 7 0 7 6 3 5 7
#  0 0 0 7 2 8 6 4 8 9 7 9 4 7 8 1 9 9 0 9 1 9 9 9 9 3 3 9 2 8 0 1 7 7 4 9 3
#  5 9 5 9 6 8 7 4 2 9 8 2 0 9 3 9 9 8 3 5 6 1 2 7 0 7 3 2 2 4 0 4 8 7 6 3 6
#  9 7 7 0 7 0 9 7 3 4 8 9 2 8 8 1 7 2 5 6 8 7 0 1 4 0 5 8 9 9 2 2 9 5 2 9 7
#  7 3 9 6 2 3 4 9 5 9 0 3 3 9 0 4 4 9 2 6 4 6 9 6 0 4 6 4 7 7 8 6 3 7 7 6 0
#  9 9 9 7 8 5 2 9 4 1 4 2 9 2 7 7 9 7 5 7 0 7 4 9 7 6 0 5 2 5 4 9 7 2 8 9 0
#  3 7 5 2 2 6 2 1 3 5 0 9 6 6 9 9 9 2 7 8 4 5 5 6 7 0 9 0 9 5 7 8 7 9 8 2 0
#  0 6 5 5 7 4 0 9 8 8 8 4 2 3 5 7 1 3 7 9 2 2 6 5 3 7 4 6 9 2 5 1 6 5 6 9 2
#  0 5 2 9 4 7 5 4 1 6 2 0 1 9 0 0 1 4 3 0 9 9 2 7 7 2 9 8 9 2 5 9 1 2 6 4 9
#  6 9 9 9 3 5 2 7 9 1 9 9 5 9 7 9 9 4 2 3 9 3 3 7 7 3 3 5 7 9 5 8 0 1 5 9 6
#  9 6 8 5 0 9 5 2 6 7 6 2 6 1 9 1 9 0 7 9 0 4 9 5 9 8 9 5 6 7 5 2 6 9 0 3 9
#  9 9 4 9 6 7 8 5 9 7 3 2 0 2 9 9 0 5 6 5 7 7 7 2 3 6 9 9 9 9 4 1 8 2 6 1 7
#  2 5 3 0 6 3 9 2 2 3 0 2 1 5 6 0 4 9 5 9 2 2 9 9 6 9 1 5 8 7 8 8 9 5 3 9 0
#  8 3 2 1 7 5 4 7 9 9 5 6 9 9 5 5 0 2 2 6 3 5 7 3 8 1 2 9 8 5 8]
#         file  prediction    values
# 0    040.wav           6  1.000000
# 1    058.wav           8  1.000000
# 2    004.wav           6  0.980502
# 3    029.wav           2  0.969107
# 4    064.wav           7  1.000000
# ..       ...         ...       ...
# 655  650.wav           2  1.000000
# 656  647.wav           9  0.999990
# 657  643.wav           8  0.941619
# 658  639.wav           5  1.000000
# 659  660.wav           8  0.979737
#
# [660 rows x 3 columns]
